# %% [markdown]
# ## Take an audio recording of a meeting, and generate minutes and actions
#
# 1. Use a frontier model to convert the audio to text
# 2. Use an open source model to generate minutes
# 3. Stream back results and show in markdown

# %% [markdown]
# # Meeting minutes creator
#
# In this colab, we make a meeting minutes program.
#
# It includes useful code to connect your Google Drive to your colab.
#
# Upload your own audio to make this work!!
#
# https://colab.research.google.com/drive/1GDIv2ihuu29SuyNV75HfMN0JGOcJit-W
#
# This should run nicely on a low-cost or free T4 box.

# %% [markdown]
# ### BUT FIRST - Something cool - really showing you how "model inference" works via OpenAI

# %%
from visualizerSM import TokenPredictor, create_token_graph, visualize_predictions

message = "In one sentence, describe the color purple to someone who has never been able to see"
message1 = "describe the cat to someone wwho has never been able to see"
model_name = "llama-3.3-70b-versatile"  

predictor = TokenPredictor(model_name)
predictions = predictor.predict_tokens(message1)
G = create_token_graph(model_name, predictions)
plt = visualize_predictions(G)
plt.show()
